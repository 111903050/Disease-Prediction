# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings('ignore')

# %%
#Importing Dataset
df = pd.read_csv('Final.csv')

# %% [markdown]
# ## DATA VISUALIZATION

# %%
#Visualising top 10 records
df.head()
# Out:
#   Valid Data Prakruti (primary-secondary) Prakruti (primary only)   Age  \
# 0        Yes                           PK                   Pitta  74.0
# 1        Yes                           KP                   Kapha  31.0
# 2        Yes                           KP                   Kapha  65.0
# 3        Yes                           PK                   Pitta  43.0
# 4        Yes                           VP                    Vata  76.0
#
#     Age Group  Gender Blood Group        BMI  BMI group Your body structure  \
# 0  51 & above  FEMALE       A +ve  23.462254     Normal              Medium
# 1    31 to 40  FEMALE       O -ve  32.550000    Obese-1               Large
# 2  51 & above    MALE       B +ve  28.827573  Pre-Obese              Medium
# 3    41 to 50  FEMALE       O +ve  29.580000    Obese-1              Medium
# 4  51 & above  FEMALE       A +ve  25.840000  Pre-Obese              Medium
#
# ...

# %%
# Basic info of columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5259 entries, 0 to 5258
# Data columns (total 57 columns):
#  #   Column                                                      Non-Null Count  Dtype
# ---  ------                                                      --------------  -----
#  0   Valid Data                                                  5259 non-null   object
#  1   Prakruti (primary-secondary)                                5259 non-null   object
#  2   Prakruti (primary only)                                     5259 non-null   object
#  3   Age                                                         4714 non-null   float64
#  4   Age Group                                                   4714 non-null   object
#  5   Gender                                                      5256 non-null   object
#  6   Blood Group                                                 4299 non-null   object
# ...

# %%
#df=dataset.drop(['Unique ID\n','Physical activity','Physical stamina','is_Hobby','Do you take an afternoon nap?','HighWorkload','How many hours do you work in a day?','How many days in a week do you stay up late in the night?','Do you spend any time in Social Welfare Activities?','How many days in a week do you exercise?','Age','Blood Group','Visibility of veins at the back of your hands','BMI','Your body structure'], axis=1)

# %%
df=df.fillna('0')

# %%
df
# Out:
#      Valid Data Prakruti (primary-secondary) Prakruti (primary only)   Age  \
# 0           Yes                           PK                   Pitta  74.0
# 1           Yes                           KP                   Kapha  31.0
# 2           Yes                           KP                   Kapha  65.0
# 3           Yes                           PK                   Pitta  43.0
# 4           Yes                           VP                    Vata  76.0
# ...         ...                          ...                     ...   ...
# 5254        Yes                           PV                   Pitta     0
# 5255        Yes                           PV                   Pitta     0
# 5256        Yes                           PV                   Pitta     0
# 5257        Yes                           PK                   Pitta     0
# 5258        Yes                           PK                   Pitta     0
#
#        Age Group  Gender Blood Group        BMI  BMI group  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5259 entries, 0 to 5258
# Data columns (total 57 columns):
#  #   Column                                                      Non-Null Count  Dtype
# ---  ------                                                      --------------  -----
#  0   Valid Data                                                  5259 non-null   object
#  1   Prakruti (primary-secondary)                                5259 non-null   object
#  2   Prakruti (primary only)                                     5259 non-null   object
#  3   Age                                                         5259 non-null   object
#  4   Age Group                                                   5259 non-null   object
#  5   Gender                                                      5259 non-null   object
#  6   Blood Group                                                 5259 non-null   object
# ...

# %%
df.columns
# Out:
# Index(['Valid Data', 'Prakruti (primary-secondary)', 'Prakruti (primary only)',
#        'Age', 'Age Group', 'Gender', 'Blood Group', 'BMI', 'BMI group',
#        'Your body structure', 'Muscle structure',
#        'Visibility of veins at the back of your hands',
#        'General feel of your skin', 'Length of your arm',
#        'Visibility of joints', 'Mobility of joints', 'Density of hair',
#        'Forehead', 'Eyes', 'Spacing between teeth', 'Palms and soles skin',
#        'Nail Length', 'Voice', 'Toe Touching', 'Body strength',
#        'Physical stamina', 'Physical activity', 'Intensity of thirst',
#        'Food & drink preference', 'Quantity of food intake during meals',
#        'Climate preference', 'Weather Intolerance', 'Sweat', 'Movement / gait',
#        'Choice of tast', 'How is your sleeping pattern?', 'Speed of Eating',
#        'Current occupation status', 'Did you undergo any major surgery yet?',
# ...

# %%
df = df.astype({"Age":'int', "BMI":'int',"Doesn't_consume_tobacco":'int',"Non Vegetarian":'int',"eats outside":'int'})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5259 entries, 0 to 5258
# Data columns (total 57 columns):
#  #   Column                                                      Non-Null Count  Dtype
# ---  ------                                                      --------------  -----
#  0   Valid Data                                                  5259 non-null   int32
#  1   Prakruti (primary-secondary)                                5259 non-null   int32
#  2   Prakruti (primary only)                                     5259 non-null   int32
#  3   Age                                                         5259 non-null   int32
#  4   Age Group                                                   5259 non-null   int32
#  5   Gender                                                      5259 non-null   int32
#  6   Blood Group                                                 5259 non-null   int32
# ...

# %%
from sklearn import preprocessing
label_encoder=preprocessing.LabelEncoder()
for col in df.columns:
    df[col]=label_encoder.fit_transform(df[col])
'''df['Age Group']=label_encoder.fit_transform(df['Age Group'])
df['General feel of your skin']=label_encoder.fit_transform(df['General feel of your skin'])
df['Length of your arm']=label_encoder.fit_transform(df['Length of your arm'])
df['Visibility of joints']=label_encoder.fit_transform(df['Visibility of joints'])
df['Mobility of joints']=label_encoder.fit_transform(df['Mobility of joints'])
#df['Density of hair']=label_encoder.fit_transform(df['Density of hair'])
df['Forehead']=label_encoder.fit_transform(df['Forehead'])
df['Eyes']=label_encoder.fit_transform(df['Eyes'])
df['Spacing between teeth']=label_encoder.fit_transform(df['Spacing between teeth'])
df['Palms and soles skin']=label_encoder.fit_transform(df['Palms and soles skin'])
df['Nail Length']=label_encoder.fit_transform(df['Nail Length'])
df['Voice']=label_encoder.fit_transform(df['Voice'])'''
# Out:
# "df['Age Group']=label_encoder.fit_transform(df['Age Group'])\ndf['General feel of your skin']=label_encoder.fit_transform(df['General feel of your skin'])\ndf['Length of your arm']=label_encoder.fit_transform(df['Length of your arm'])\ndf['Visibility of joints']=label_encoder.fit_transform(df['Visibility of joints'])\ndf['Mobility of joints']=label_encoder.fit_transform(df['Mobility of joints'])\n#df['Density of hair']=label_encoder.fit_transform(df['Density of hair'])\ndf['Forehead']=label_encoder.fit_transform(df['Forehead'])\ndf['Eyes']=label_encoder.fit_transform(df['Eyes'])\ndf['Spacing between teeth']=label_encoder.fit_transform(df['Spacing between teeth'])\ndf['Palms and soles skin']=label_encoder.fit_transform(df['Palms and soles skin'])\ndf['Nail Length']=label_encoder.fit_transform(df['Nail Length'])\ndf['Voice']=label_encoder.fit_transform(df['Voice'])"

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5259 entries, 0 to 5258
# Data columns (total 57 columns):
#  #   Column                                                      Non-Null Count  Dtype
# ---  ------                                                      --------------  -----
#  0   Valid Data                                                  5259 non-null   int64
#  1   Prakruti (primary-secondary)                                5259 non-null   int64
#  2   Prakruti (primary only)                                     5259 non-null   int64
#  3   Age                                                         5259 non-null   int64
#  4   Age Group                                                   5259 non-null   int64
#  5   Gender                                                      5259 non-null   int64
#  6   Blood Group                                                 5259 non-null   int64
# ...

# %%
df.corr()
# Out:
#                                                     Valid Data  \
# Valid Data                                                 NaN
# Prakruti (primary-secondary)                               NaN
# Prakruti (primary only)                                    NaN
# Age                                                        NaN
# Age Group                                                  NaN
# Gender                                                     NaN
# Blood Group                                                NaN
# BMI                                                        NaN
# BMI group                                                  NaN
# Your body structure                                        NaN
# Muscle structure                                           NaN
# Visibility of veins at the back of your hands              NaN
# General feel of your skin                                  NaN
# Length of your arm                                         NaN
# ...

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(), annot=True, fmt='.1f')
plt.show()

# %%
df.is_HeartDiseases.value_counts()
# Out:
# 0    4599
# 1     660
# Name: is_HeartDiseases, dtype: int64

# %%
countNoDisease = len(df[df.is_HeartDiseases == 0])
countHaveDisease = len(df[df.is_HeartDiseases == 1])
print("Percentage of patients dont have Diabetes: {:.2f}%".format((countNoDisease/(len(df.is_HeartDiseases)))*100))
print("Percentage of patients have Diabetes: {:.2f}%".format((countHaveDisease/(len(df.is_HeartDiseases)))*100))
# Out:
# Percentage of patients dont have Diabetes: 87.45%
# Percentage of patients have Diabetes: 12.55%

# %%
df=df.drop(['Blood Group'],axis=1)

# %%
Data = df.drop(['is_HeartDiseases'],axis =1)
is_diabetes = df.is_HeartDiseases.values

# %%
# Created a common function to plot confusion matrix
def Plot_confusion_matrix(y_test, pred_test):
  cm = confusion_matrix(y_test, pred_test)
  plt.clf()
  plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Accent)
  categoryNames = ['Non-Fraudalent','Fraudalent']
  plt.title('Confusion Matrix - Test Data')
  plt.ylabel('True label')
  plt.xlabel('Predicted label')
  ticks = np.arange(len(categoryNames))
  plt.xticks(ticks, categoryNames, rotation=45)
  plt.yticks(ticks, categoryNames)
  s = [['TN','FP'], ['FN', 'TP']]
  
  for i in range(2):
      for j in range(2):
          plt.text(j,i, str(s[i][j])+" = "+str(cm[i][j]),fontsize=12)
  plt.show()

# %%
x_train,x_test,y_train,y_test = train_test_split(Data,is_diabetes, test_size=0.3, random_state=1)

# %%
from sklearn import linear_model
from sklearn.model_selection import KFold
from sklearn.metrics import classification_report,confusion_matrix
# Created a common function to plot confusion matrix
def Plot_confusion_matrix(y_test, pred_test):
  cm = confusion_matrix(y_test, pred_test)
  plt.clf()
  plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Accent)
  categoryNames = ['Non-DIabetis','Diabetic']
  plt.title('Confusion Matrix - Test Data')
  plt.ylabel('True label')
  plt.xlabel('Predicted label')
  ticks = np.arange(len(categoryNames))
  plt.xticks(ticks, categoryNames, rotation=45)
  plt.yticks(ticks, categoryNames)
  s = [['TN','FP'], ['FN', 'TP']]
  
  for i in range(2):
      for j in range(2):
          plt.text(j,i, str(s[i][j])+" = "+str(cm[i][j]),fontsize=12)
  plt.show()

num_C = list(np.power(10.0, np.arange(-10, 10)))
cv_num = KFold(n_splits=10, shuffle=True, random_state=42)
searchCV_l1 = linear_model.LogisticRegressionCV(
          Cs=num_C
          ,penalty='l1'
          ,scoring='roc_auc'
          ,cv=cv_num
          ,random_state=42
          ,max_iter=10000
          ,fit_intercept=True
          ,solver='liblinear'
          ,tol=10
      )
searchCV_l1.fit(x_train, y_train)
#find predicted vallues
y_pred_l1 = searchCV_l1.predict(x_test)
Plot_confusion_matrix(y_test, y_pred_l1)

# %%
df.corr()
# Out:
#                                                     Valid Data  \
# Valid Data                                                 NaN
# Prakruti (primary-secondary)                               NaN
# Prakruti (primary only)                                    NaN
# Age                                                        NaN
# Age Group                                                  NaN
# Gender                                                     NaN
# BMI                                                        NaN
# BMI group                                                  NaN
# Your body structure                                        NaN
# Muscle structure                                           NaN
# Visibility of veins at the back of your hands              NaN
# General feel of your skin                                  NaN
# Length of your arm                                         NaN
# Visibility of joints                                       NaN
# ...

# %%
df
# Out:
#       Valid Data  Prakruti (primary-secondary)  Prakruti (primary only)  Age  \
# 0              0                             2                        1   65
# 1              0                             0                        0   22
# 2              0                             0                        0   56
# 3              0                             2                        1   34
# 4              0                             5                        2   67
# ...          ...                           ...                      ...  ...
# 5254           0                             3                        1    0
# 5255           0                             3                        1    0
# 5256           0                             3                        1    0
# 5257           0                             2                        1    0
# 5258           0                             2                        1    0
#
# ...

# %%
# Logistic Regression 
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
regressor = LogisticRegression()
regressor.fit(x_train,y_train)
print('Test Accuracy {:.2f}%'.format(regressor.score(x_test, y_test)*100))
# Out:
# Test Accuracy 88.85%

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(x_train,y_train)
print('KNN Accuracy {:.2f}%'.format(knn.score(x_test,y_test)*100))
# Out:
# KNN Accuracy 94.80%

# %%
from sklearn.svm import SVC
svm = SVC(random_state=1)
svm1 = SVC(kernel='linear',gamma='scale',random_state=0)
svm2 = SVC(kernel='rbf',gamma='scale',random_state=0)
svm3 = SVC(kernel='poly',gamma='scale',random_state=0)
svm4 = SVC(kernel='sigmoid',gamma='scale',random_state=0)

svm.fit(x_train,y_train)
svm1.fit(x_train,y_train)
svm2.fit(x_train,y_train)
svm3.fit(x_train,y_train)
svm4.fit(x_train,y_train)

print('SVC Accuracy : {:,.2f}%'.format(svm.score(x_test,y_test)*100))

print('SVC Liner Accuracy : {:,.2f}%'.format(svm1.score(x_test,y_test)*100))

print('SVC RBF Accuracy : {:,.2f}%'.format(svm2.score(x_test,y_test)*100))

print('SVC Ploy Accuracy : {:,.2f}%'.format(svm3.score(x_test,y_test)*100))

print('SVC Sigmoid Accuracy : {:,.2f}%'.format(svm4.score(x_test,y_test)*100))
# Out:
# SVC Accuracy : 95.82%
# SVC Liner Accuracy : 95.82%
# SVC RBF Accuracy : 95.82%
# SVC Ploy Accuracy : 95.82%
# SVC Sigmoid Accuracy : 95.82%

# %%
# Naive Bayes
from sklearn.naive_bayes import GaussianNB
nb = GaussianNB()
nb.fit(x_train,y_train)
print("Naive Bayes Accuracy : {:,.2f}%".format(nb.score(x_test,y_test)*100))
# Out:
# Naive Bayes Accuracy : 90.05%

# %%
# Random Forest Classifier

from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=1000, max_depth=100,random_state=1)
rf.fit(x_train,y_train)
print("Random Forest Accuracy : {:,.2f}%".format(rf.score(x_test,y_test)*100))
# Out:
# Random Forest Accuracy : 95.63%

# %%
# Decision Tree
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier(criterion='entropy',max_depth=4, random_state=0)
dt.fit(x_train,y_train)
print("Decision Tree Accuracy : {:,.2f}%".format(dt.score(x_test,y_test)*100))
# Out:
# Decision Tree Accuracy : 95.69%

# %%
# XGboost
import xgboost
xg = xgboost.XGBClassifier()
xg.fit(x_train,y_train)
print("XGboost accuracy : {:.2f}%".format(xg.score(x_test,y_test)*100))
# Out:
# XGboost accuracy : 94.87%

# %% [markdown]
# # VALIDATION

# %%
# Logistic Regression
from sklearn import linear_model #import the package
from sklearn.model_selection import KFold

num_C = list(np.power(10.0, np.arange(-10, 10)))
cv_num = KFold(n_splits=10, shuffle=True, random_state=42)

clf = linear_model.LogisticRegressionCV(
          Cs= num_C
          ,penalty='l2'
          ,scoring='roc_auc'
          ,cv=cv_num
          ,random_state=42
          ,max_iter=10000
          ,fit_intercept=True
          ,solver='newton-cg'
          ,tol=10
      )

clf.fit(x_train,y_train)
print ('Max auc_roc for l2:', clf.scores_[1].mean(axis=0).max())


print("Parameters for l2 regularisations")
print(clf.coef_)
print(clf.intercept_) 
print(clf.scores_) 


#find predicted vallues
y_pred_l2 = clf.predict(x_test)


#Find predicted probabilities
y_pred_probs_l2 = clf.predict_proba(x_test)[:,1] 


# Accuaracy of L2/L1 models
Accuracy_l2 = metrics.accuracy_score(y_pred=y_pred_l2, y_true=y_test)


print("Accuarcy of Logistic model with l2 regularisation : {0}".format(Accuracy_l2))


from sklearn.metrics import roc_auc_score
l2_roc_value = roc_auc_score(y_test, y_pred_probs_l2)
print("l2 roc_value: {0}" .format(l2_roc_value))
fpr, tpr, thresholds = metrics.roc_curve(y_test, y_pred_probs_l2)
threshold = thresholds[np.argmax(tpr-fpr)]
print("l2 threshold: {0}".format(threshold))
# Out:
# Max auc_roc for l2: 0.7485303189345184
# Parameters for l2 regularisations
# [[-0.02919118 -0.01921347 -0.00941464  0.37906301 -0.41937978  0.06559647
#   -0.07879255  0.15788301  0.10733791  0.2146101  -0.10575509 -0.20261149
#   -0.16418321  0.02730868  0.0981542   0.18014062 -0.04429262  0.03385436
#   -0.08231297  0.05379246  0.02614287 -0.18411005]]
# [-2.88817033]
# {1: array([[0.64394476, 0.64394476, 0.64394476, 0.64394476, 0.64394476,
#         0.62411473, 0.60729462, 0.61685552, 0.66041076, 0.67652266,
#         0.67174221, 0.67174221, 0.67174221, 0.67174221, 0.67174221,
#         0.67174221, 0.67174221, 0.67174221, 0.67174221, 0.67174221],
#        [0.69023314, 0.69023314, 0.69023314, 0.69035917, 0.69010712,
#         0.68771267, 0.71039698, 0.70497795, 0.72098299, 0.71707624,
#         0.71707624, 0.71707624, 0.71707624, 0.71707624, 0.71707624,
#         0.71707624, 0.71707624, 0.71707624, 0.71707624, 0.71707624],
# ...

# %%
# Checking for the coefficient values
clf.coef_
# Out:
# array([[-0.02919118, -0.01921347, -0.00941464,  0.37906301, -0.41937978,
#          0.06559647, -0.07879255,  0.15788301,  0.10733791,  0.2146101 ,
#         -0.10575509, -0.20261149, -0.16418321,  0.02730868,  0.0981542 ,
#          0.18014062, -0.04429262,  0.03385436, -0.08231297,  0.05379246,
#          0.02614287, -0.18411005]])

# %%
# Creating a dataframe with the coefficient values
coefficients = pd.concat([pd.DataFrame(Data.columns),pd.DataFrame(np.transpose(clf.coef_))], axis = 1)
coefficients.columns = ['Feature','Importance Coefficient']

# %%
# Plotting the coefficient values
plt.figure(figsize=(20,5))
sns.barplot(x='Feature', y='Importance Coefficient', data=coefficients)
plt.title("Logistic Regression with L2 Regularisation Feature Importance", fontsize=18)

plt.show()

# %%
cols = x_train.columns
cols
# Out:
# Index(['Valid Data', 'Prakruti (primary-secondary)', 'Prakruti (primary only)',
#        'Age Group', 'Gender', 'BMI group', 'Muscle structure',
#        'Density of hair', 'Body strength', 'Intensity of thirst',
#        'Food & drink preference', 'Quantity of food intake during meals',
#        'Climate preference', 'Sweat', 'Did you undergo any major surgery yet?',
#        'is_Late', 'Is_Latenight', 'Doesn't_consume_tobacco',
#        'Does_consumeAlcohole', 'Non Vegetarian', 'Eats outside',
#        'Frequency of irregular meals?'],
#       dtype='object')

# %%
for col in df2.columns:
    print(col, ': ', len(df2[col].unique()),'labels')
# Out:
# Valid Data :  1 labels
# Prakruti (primary-secondary) :  6 labels
# Prakruti (primary only) :  3 labels
# Age Group :  5 labels
# Gender :  2 labels
# BMI group :  8 labels
# Muscle structure :  5 labels
# Density of hair :  5 labels
# Body strength :  5 labels
# Intensity of thirst :  4 labels
# Food & drink preference :  6 labels
# Quantity of food intake during meals :  4 labels
# Climate preference :  5 labels
# Sweat :  4 labels
# Did you undergo any major surgery yet? :  2 labels
# is_Late :  2 labels
# Is_Latenight :  2 labels
# Doesn't_consume_tobacco :  2 labels
# Does_consumeAlcohole :  2 labels
# Non Vegetarian :  2 labels
# Eats outside :  2 labels
# Frequency of irregular meals? :  9 labels
# is_diabetes :  2 labels

# %%
pd.get_dummies(df2,drop_first=True).shape
# Out:
# (5259, 23)

# %%
df3 = pd.read_csv('DataVisualization.csv')

# %%
df4=df2[df2['is_diabetes']==0].sample(1500,random_state=0)

# %%
df4
# Out:
#       Valid Data  Prakruti (primary-secondary)  Prakruti (primary only)  \
# 4844           1                            12                        1
# 1599           1                            12                        1
# 568            1                            12                        1
# 831            1                            12                        1
# 3937           1                            13                        1
# ...          ...                           ...                      ...
# 1363           1                            21                        2
# 5121           1                            31                        3
# 2411           1                            12                        1
# 1447           1                            21                        2
# 2184           1                            12                        1
#
#       Age Group  Gender  BMI group  Muscle structure  Density of hair  \
# ...

# %%
df5=df2[df2['is_diabetes']==1].sample(260,random_state=0)

# %%
df5
# Out:
#       Valid Data  Prakruti (primary-secondary)  Prakruti (primary only)  \
# 4440           1                            23                        2
# 3624           1                            31                        3
# 4488           1                            12                        1
# 3187           1                            12                        1
# 3998           1                            12                        1
# ...          ...                           ...                      ...
# 3120           1                            12                        1
# 4123           1                            12                        1
# 3688           1                            13                        1
# 2983           1                            21                        2
# 3994           1                            12                        1
#
#       Age Group  Gender  BMI group  Muscle structure  Density of hair  \
# ...

# %%
df6= pd.concat([df4,df5], ignore_index=True).sample(1760,random_state=0)

# %%
df6
# Out:
#       Valid Data  Prakruti (primary-secondary)  Prakruti (primary only)  \
# 1164           1                            13                        1
# 668            1                            13                        1
# 412            1                            21                        2
# 558            1                            12                        1
# 1232           1                            12                        1
# ...          ...                           ...                      ...
# 835            1                            21                        2
# 1216           1                            12                        1
# 1653           1                            12                        1
# 559            1                            12                        1
# 684            1                            21                        2
#
#       Age Group  Gender  BMI group  Muscle structure  Density of hair  \
# ...

# %%
df6.to_csv('data.csv')
